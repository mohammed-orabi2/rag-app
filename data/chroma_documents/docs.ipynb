# %%
import json

with open("chroma_documents.json", "r", encoding="utf-8") as f:
    chroma_documents = json.load(f)


page_content = chroma_documents[917]["page_content"]
print(page_content)
# Out:
# # 🎓 Bachelor of Business Administration
#
# **School:** International University of Monaco (OMNES Group)
# **Program Type:** Bachelor
# **School Type:** Ecole Spécialisée
# **Field:** Business School
# **Rank:** Unranked
# **Price Range:** Price not available
# **Available Specializations:** no specializations
#
# ## 📅 Year 1 Entry
#
# ### 📆 **INTAKE INFORMATION**
# --------------------
# **Intake Periods:** Spring
#
# **Program Requirements:**
# • Entry Level: BAC
# • Campuses: Monaco
# • Language: English
# • Price: €15162.0
# • Duration: 3.0 year(s)
# • Alternance: Not_Available
# • Live in EU Required: No
#
# ### 🎯 **SPECIALIZATIONS**
# **No specific specializations available for this year.**
#
#
# ## 📅 Year 2 Entry
#
# ### 📆 **INTAKE INFORMATION**
# --------------------
# **Intake Periods:** Fall
#
# **Program Requirements:**
# • Entry Level: BAC1
# • Campuses: Monaco
# • Language: English
# • Price: €16118.0
# • Duration: 2.0 year(s)
# • Alternance: Not_Available
# ...
