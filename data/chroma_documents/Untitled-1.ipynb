# %%
import json
with open('chroma_documents.json', 'r', encoding='utf-8') as f:
    documents = json.load(f)

# %%
print(documents[3]['page_content'])
# Out:
# # 🎓 Master in Management (Master Grande Ecole)
#
# **School:** EXCELIA Business School
# **Program Type:** Master
# **School Type:** Grande Ecole
# **Field:** Business School
# **Rank:** top 20
# **Price Range:** from €14000 to €15100
# **Available Specializations:** All Masters of Science are available
#
# ## 📅 Year 1 Entry
#
# ### 📆 **INTAKE INFORMATION**
# --------------------
# **Intake Periods:** Fall
#
# **Program Requirements:**
# • Entry Level: BAC
# • Campuses: La Rochelle, Paris, Tours
# • Language: Both
# • Price: €14000
# • Duration: 5 year(s)
# • Alternance: Not_Available
# • Live in EU Required: No
#
# ### 🎯 **SPECIALIZATIONS**
# **No specific specializations available for this year.**
#
#
# ## 📅 Year 2 Entry
#
# ### 📆 **INTAKE INFORMATION**
# --------------------
# **Intake Periods:** Fall
#
# **Program Requirements:**
# • Entry Level: BAC+1
# • Campuses: La Rochelle, Paris, Tours
# • Language: Both
# • Price: €14000
# • Duration: 4 year(s)
# • Alternance: Not_Available
# • Live in EU Required: No
#
# ### 🎯 **SPECIALIZATIONS**
# **No specific specializations available for this year.**
#
#
# ## 📅 Year 3 Entry
#
# ### 📆 **INTAKE INFORMATION**
# --------------------
# **Intake Periods:** Fall
#
# **Program Requirements:**
# • Entry Level: BAC+2
# • Campuses:
# • Language: French
# • Price: €15100
# • Duration: 3 year(s)
# • Alternance: Not_Available
# • Live in EU Required: No
#
# ### 🎯 **SPECIALIZATIONS**
# **No specific specializations available for this year.**
#
#
# ## 📅 Year 4 Entry
#
# ### 📆 **INTAKE INFORMATION**
# --------------------
# **Intake Periods:** Fall
#
# **Program Requirements:**
# • Entry Level: BAC+3
# • Campuses: La Rochelle, Paris, Tours
# • Language: French
# • Price: €15100
# • Duration: 2 year(s)
# • Alternance: Alternance_Only
# • Live in EU Required: Yes
#
# ### 🎯 **SPECIALIZATIONS**
# **No specific specializations available for this year.**
#
#
# ## 📅 Year 5 Entry
#
# ### 📆 **INTAKE INFORMATION**
# --------------------
# **Intake Periods:** N/A
#
# **Program Requirements:**
# • Entry Level: BAC+4
# • Campuses: La Rochelle, Paris, Tours
# • Language: French
# • Price: €15100
# • Duration: 1 year(s)
# • Alternance: Alternance_Only
# • Live in EU Required: Yes
#
# ### 🎯 **SPECIALIZATIONS AVAILABLE**
# ----------------------------------------
# **Total Specializations Available:** 1
# #### **1. All Masters of Science are available**
#   Intake: Fall
#   Campuses: La Rochelle, Paris, Tours
#   Language: Both
#   Alternance: Available
#
# --------End of program--------
